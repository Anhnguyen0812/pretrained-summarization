# %% [markdown]
# # Causal LM Summarization: Small Qwen / DeepSeek LoRA
#
# Notebook nay chay them causal LM LoRA trong cung repo. Tat ca model trong cell mac dinh deu <3B tham so. Mac dinh chay Qwen3-1.7B LoRA; Qwen2.5-1.5B va DeepSeek-R1-Distill-Qwen-1.5B tat mac dinh.

# %%
from pathlib import Path
import json
import os
import shutil
import subprocess
import sys
from zipfile import ZipFile

PROJECT_NAME = 'pretrained-summarization'
REPO_URL = 'https://github.com/Anhnguyen0812/pretrained-summarization.git'
REFRESH_REPO = True
WORKING = Path('/kaggle/working')
WORKING_REPO = WORKING / PROJECT_NAME
OUTPUT_ROOT = WORKING / 'summarization_outputs'
DATA_DIR = Path('/kaggle/input/datasets/anhnguyen0812/nlp-vietnamese-sumarization')
TRAIN_FILE = DATA_DIR / 'train-00000-of-00001.parquet'
VALID_FILE = DATA_DIR / 'valid-00000-of-00001.parquet'

os.chdir(WORKING)
OUTPUT_ROOT.mkdir(parents=True, exist_ok=True)

def run(cmd, cwd=None, check=True):
    print('CMD:', cmd, flush=True)
    env = os.environ.copy()
    env['PYTHONUNBUFFERED'] = '1'
    process = subprocess.Popen(cmd, shell=True, cwd=str(cwd) if cwd else None, env=env, stdout=subprocess.PIPE, stderr=subprocess.STDOUT, text=True, bufsize=1)
    lines=[]
    for line in process.stdout:
        print(line, end='', flush=True)
        lines.append(line)
    code=process.wait()
    if check and code != 0:
        raise RuntimeError(f'Command failed with exit code {code}: {cmd}\nLast lines:\n{"".join(lines[-100:])}')
    return code

def is_repo(path):
    return (path / 'pyproject.toml').exists() and (path / 'src' / 'vn_summarization').exists()

if REFRESH_REPO and WORKING_REPO.exists():
    shutil.rmtree(WORKING_REPO)
if not is_repo(WORKING_REPO):
    run(f'git clone --depth 1 {REPO_URL} {WORKING_REPO}', cwd=WORKING)
else:
    run('git pull --ff-only', cwd=WORKING_REPO, check=False)
repo = WORKING_REPO
run('git log --oneline -1', cwd=repo)

configs_dir = repo / 'configs'

def write_causal_lora_config(path, model_name, output_dir, prompt_template):
    if path.exists():
        return
    prompt_yaml = json.dumps(prompt_template, ensure_ascii=False)
    path.write_text(f'''model:
  name_or_path: {model_name}
  use_fast_tokenizer: true
  trust_remote_code: false
  cache_dir:
  padding_side: right
  torch_dtype: float16
  max_parameters: 3000000000

data:
  train_file: ../train-00000-of-00001.parquet
  valid_file: ../valid-00000-of-00001.parquet
  max_source_length: 768
  max_target_length: 128
  max_length: 896
  preprocessing_num_proc: 1
  max_train_samples: 2500
  max_eval_samples: 120
  prompt_template: {prompt_yaml}

training:
  output_dir: {output_dir}
  overwrite_output_dir: false
  seed: 42
  precision: fp16
  per_device_train_batch_size: 1
  per_device_eval_batch_size: 2
  gradient_accumulation_steps: 8
  num_train_epochs: 2
  max_steps: 300
  learning_rate: 0.0001
  weight_decay: 0.01
  warmup_ratio: 0.03
  lr_scheduler_type: cosine
  optim: adamw_torch
  gradient_checkpointing: true
  strategy: steps
  save_strategy: steps
  eval_steps: 300
  save_steps: 300
  logging_steps: 25
  save_total_limit: 2
  load_best_model_at_end: true
  metric_for_best_model: eval_loss
  greater_is_better: false
  report_to:
    - tensorboard
  save_safetensors: true

generation:
  max_new_tokens: 128
  num_beams: 1
  do_sample: false
  no_repeat_ngram_size: 3
  repetition_penalty: 1.08

lora:
  enabled: true
  r: 8
  lora_alpha: 16
  lora_dropout: 0.05
  target_modules:
    - q_proj
    - k_proj
    - v_proj
    - o_proj
    - gate_proj
    - up_proj
    - down_proj
''', encoding='utf-8')

base_prompt = 'Bạn là trợ lý tóm tắt tiếng Việt. Viết duy nhất một đoạn tóm tắt ngắn, trung lập, đủ ý chính. Giữ tên riêng, số liệu, mốc thời gian quan trọng. Không thêm thông tin ngoài văn bản, không giải thích.\n\nVăn bản:\n{article}\n\nTóm tắt:\n'
no_think_prompt = 'Bạn là trợ lý tóm tắt tiếng Việt. Viết duy nhất một đoạn tóm tắt cuối cùng, không viết suy luận, không giải thích, không dùng thẻ <think>. Giữ tên riêng, số liệu, mốc thời gian quan trọng. Không thêm thông tin ngoài văn bản.\n\nVăn bản:\n{article}\n\nTóm tắt:\n'
small_configs = [
    ('qwen3_1_7b_lora.yaml', 'Qwen/Qwen3-1.7B', 'outputs/qwen3_1_7b_lora', no_think_prompt),
    ('qwen25_1_5b_lora.yaml', 'Qwen/Qwen2.5-1.5B-Instruct', 'outputs/qwen25_1_5b_lora', base_prompt),
    ('deepseek_r1_distill_qwen_1_5b_lora.yaml', 'deepseek-ai/DeepSeek-R1-Distill-Qwen-1.5B', 'outputs/deepseek_r1_distill_qwen_1_5b_lora', no_think_prompt),
]
for file_name, model_name, output_dir, prompt in small_configs:
    write_causal_lora_config(configs_dir / file_name, model_name, output_dir, prompt)
print('SMALL_CAUSAL_CONFIGS', [file_name for file_name, *_ in small_configs])
# Out:
# CMD: git clone --depth 1 https://github.com/Anhnguyen0812/pretrained-summarization.git /kaggle/working/pretrained-summarization
# Cloning into '/kaggle/working/pretrained-summarization'...
# CMD: git log --oneline -1
# f3e3433 Revise report notebook for controlled ablations
# SMALL_CAUSAL_CONFIGS ['qwen3_1_7b_lora.yaml', 'qwen25_1_5b_lora.yaml', 'deepseek_r1_distill_qwen_1_5b_lora.yaml']

# %%
os.chdir(repo)
run(f'{sys.executable} -m pip install -q --upgrade pip', cwd=repo)
run(f'{sys.executable} -m pip install -q -e .', cwd=repo)
run(f'{sys.executable} -m pip install -q --upgrade "transformers>=4.51.0,<5" "tokenizers>=0.22.0,<=0.23.0"', cwd=repo)
run(f'{sys.executable} -m pip check', cwd=repo, check=False)
run(f'{sys.executable} -m pip show transformers tokenizers peft accelerate | sed -n "/Name: /p;/Version: /p"', cwd=repo, check=False)
run(f"{sys.executable} -c 'import tokenizers, transformers; print(\"TRANSFORMERS\", transformers.__version__); print(\"TOKENIZERS\", tokenizers.__version__)'", cwd=repo)
# Out:
# CMD: /usr/bin/python3 -m pip install -q --upgrade pip
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 59.4 MB/s eta 0:00:00
# CMD: /usr/bin/python3 -m pip install -q -e .
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dask-cuda 26.2.0 requires cuda-core==0.3.*, but you have cuda-core 1.0.1 which is incompatible.
# dask-cuda 26.2.0 requires numba-cuda<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# distributed-ucxx-cu12 0.48.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# cuml-cu12 26.2.0 requires numba<0.62.0,>=0.60.0, but you have numba 0.65.1 which is incompatible.
# cuml-cu12 26.2.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# ucxx-cu12 0.48.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# cudf-cu12 26.2.1 requires numba<0.62.0,>=0.60.0, but you have numba 0.65.1 which is incompatible.
# cudf-cu12 26.2.1 requires numba-cuda[cu12]<0.23.0,>=0.22.2, but you have numba-cuda 0.30.2 which is incompatible.
# CMD: /usr/bin/python3 -m pip install -q --upgrade "transformers>=4.51.0,<5" "tokenizers>=0.22.0,<=0.23.0"
# CMD: /usr/bin/python3 -m pip check
# bigframes 2.39.0 requires google-cloud-bigquery-storage, which is not installed.
# google-adk 1.29.0 requires google-cloud-bigquery-storage, which is not installed.
# ydata-profiling 4.18.4 has requirement numba<0.63,>=0.60, but you have numba 0.65.1.
# ydata-profiling 4.18.4 has requirement numpy<2.4,>=1.22, but you have numpy 2.4.6.
# google-colab 1.0.0 has requirement jupyter-server==2.14.0, but you have jupyter-server 2.12.5.
# google-colab 1.0.0 has requirement pandas==2.2.2, but you have pandas 2.3.3.
# dask-cuda 26.2.0 has requirement cuda-core==0.3.*, but you have cuda-core 1.0.1.
# dask-cuda 26.2.0 has requirement numba-cuda<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2.
# dopamine-rl 4.1.2 has requirement gym<=0.25.2, but you have gym 0.26.2.
# distributed-ucxx-cu12 0.48.0 has requirement numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2.
# moviepy 1.0.3 has requirement decorator<5.0,>=4.0.2, but you have decorator 5.3.1.
# cuml-cu12 26.2.0 has requirement numba<0.62.0,>=0.60.0, but you have numba 0.65.1.
# cuml-cu12 26.2.0 has requirement numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2.
# ucxx-cu12 0.48.0 has requirement numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2.
# tensorflow 2.19.0 has requirement numpy<2.2.0,>=1.26.0, but you have numpy 2.4.6.
# cudf-cu12 26.2.1 has requirement numba<0.62.0,>=0.60.0, but you have numba 0.65.1.
# cudf-cu12 26.2.1 has requirement numba-cuda[cu12]<0.23.0,>=0.22.2, but you have numba-cuda 0.30.2.
# CMD: /usr/bin/python3 -m pip show transformers tokenizers peft accelerate | sed -n "/Name: /p;/Version: /p"
# Name: transformers
# Version: 4.57.6
# Name: tokenizers
# Version: 0.22.2
# Name: peft
# Version: 0.18.1
# Name: accelerate
# Version: 1.13.0
# CMD: /usr/bin/python3 -c 'import tokenizers, transformers; print("TRANSFORMERS", transformers.__version__); print("TOKENIZERS", tokenizers.__version__)'
# TRANSFORMERS 4.57.6
# TOKENIZERS 0.22.2
# 0

# %%
os.environ['TOKENIZERS_PARALLELISM'] = 'false'
os.environ['PYTORCH_CUDA_ALLOC_CONF'] = 'expandable_segments:True'
run('nvidia-smi', check=False)
print('TRAIN_FILE:', TRAIN_FILE, TRAIN_FILE.exists())
print('VALID_FILE:', VALID_FILE, VALID_FILE.exists())
if not TRAIN_FILE.exists() or not VALID_FILE.exists():
    raise FileNotFoundError('Attach Kaggle dataset first.')

import torch
NUM_GPUS = torch.cuda.device_count() if torch.cuda.is_available() else 0
print('NUM_GPUS', NUM_GPUS)
# Out:
# CMD: nvidia-smi
# Wed Jun 10 06:10:28 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.105.08             Driver Version: 580.105.08     CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   37C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  Tesla T4                       Off |   00000000:00:05.0 Off |                    0 |
# | N/A   45C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
# TRAIN_FILE: /kaggle/input/datasets/anhnguyen0812/nlp-vietnamese-sumarization/train-00000-of-00001.parquet True
# VALID_FILE: /kaggle/input/datasets/anhnguyen0812/nlp-vietnamese-sumarization/valid-00000-of-00001.parquet True
# NUM_GPUS 2

# %%
BASE_OVERRIDES = [
    f'data.train_file={TRAIN_FILE}',
    f'data.valid_file={VALID_FILE}',
]
RUN_CONFIGS = {}

def _override_string(items):
    return ' '.join(f'--set {item}' for item in items)

def latest_checkpoint(run_dir):
    checkpoints = sorted(run_dir.glob('checkpoint-*'), key=lambda p: int(p.name.split('-')[-1]) if p.name.split('-')[-1].isdigit() else -1)
    return checkpoints[-1] if checkpoints else None

def train_causal(run_name, config_path, overrides=None, overwrite=False):
    run_dir = OUTPUT_ROOT / run_name
    RUN_CONFIGS[run_name] = config_path
    if (run_dir / 'best' / 'adapter_config.json').exists() and not overwrite:
        print('SKIP train, adapter exists:', run_dir / 'best')
        return 0
    resume = []
    if run_dir.exists() and not overwrite:
        ckpt = latest_checkpoint(run_dir)
        if ckpt:
            print('RESUME', ckpt)
            resume = [f'training.resume_from_checkpoint={ckpt}']
        else:
            print('CLEAR incomplete run:', run_dir)
            shutil.rmtree(run_dir)
    final_overrides = BASE_OVERRIDES + [f'training.output_dir={run_dir}'] + resume + (overrides or [])
    train_cmd = f'-m vn_summarization.train_causal_lm --config {config_path} {_override_string(final_overrides)}'
    if NUM_GPUS >= 2:
        cmd = f'{sys.executable} -m accelerate.commands.launch --multi_gpu --num_processes {NUM_GPUS} --num_machines 1 --mixed_precision fp16 --dynamo_backend no {train_cmd}'
    else:
        cmd = f'{sys.executable} -u {train_cmd}'
    return run(cmd, cwd=repo)

def eval_causal(eval_name, config_path, model_path, overrides=None, overwrite=False):
    eval_dir = OUTPUT_ROOT / eval_name
    if (eval_dir / 'validation_metrics.json').exists() and not overwrite:
        print('SKIP eval:', eval_dir / 'validation_metrics.json')
        return 0
    eval_dir.mkdir(parents=True, exist_ok=True)
    final_overrides = BASE_OVERRIDES + [f'training.output_dir={eval_dir}'] + (overrides or [])
    cmd = (
        f'{sys.executable} -u -m vn_summarization.evaluate_causal_lm '
        f'--config {config_path} --model_path {model_path} '
        f'--predictions_path {eval_dir / "predictions_valid.jsonl"} '
        f'{_override_string(final_overrides)}'
    )
    return run(cmd, cwd=repo)

def summarize_results():
    return run(f'{sys.executable} -u -m vn_summarization.summarize_results --root {OUTPUT_ROOT}', cwd=repo, check=False)

# %% [markdown]
# ## Run Flags
#
# Mac dinh: Qwen3-1.7B LoRA profile chuan hon ~4-6h tren Kaggle T4x2. Profile nay dung max_steps=1000, 10000 train samples, 500 eval samples, source length 1024, LoRA r16. Bat DeepSeek lai neu muon so sanh them, nhung tong thoi gian se tang.

# %%
RUN_QWEN3 = True
RUN_QWEN25 = False
RUN_DEEPSEEK = False
OVERWRITE_RUNS = False
OVERWRITE_EVALS = False

COMMON_CAUSAL = [
    'training.num_train_epochs=1',
    'training.max_steps=1000',
    'training.eval_steps=250',
    'training.save_steps=250',
    'training.logging_steps=25',
    'training.save_total_limit=2',
    'training.ddp_find_unused_parameters=false',
    'training.per_device_train_batch_size=1',
    'training.per_device_eval_batch_size=2',
    'training.gradient_accumulation_steps=8',
    'data.max_train_samples=10000',
    'data.max_eval_samples=500',
    'data.max_source_length=1024',
    'data.max_target_length=160',
    'data.max_length=1184',
    'generation.max_new_tokens=160',
    'generation.num_beams=2',
    'lora.r=16',
    'lora.lora_alpha=32',
]

EXPERIMENTS=[]
if RUN_QWEN3:
    EXPERIMENTS.append({
        'name': 'qwen3_1_7b_lora_4to6h_t4x2',
        'config': 'configs/qwen3_1_7b_lora.yaml',
        'overrides': COMMON_CAUSAL,
    })
if RUN_QWEN25:
    EXPERIMENTS.append({
        'name': 'qwen25_1_5b_lora_4to6h_t4x2',
        'config': 'configs/qwen25_1_5b_lora.yaml',
        'overrides': COMMON_CAUSAL,
    })
if RUN_DEEPSEEK:
    EXPERIMENTS.append({
        'name': 'deepseek_r1_qwen_1_5b_lora_4to6h_t4x2',
        'config': 'configs/deepseek_r1_distill_qwen_1_5b_lora.yaml',
        'overrides': COMMON_CAUSAL,
    })
print(json.dumps(EXPERIMENTS, indent=2))
# Out:
# [
#   {
#     "name": "qwen3_1_7b_lora_4to6h_t4x2",
#     "config": "configs/qwen3_1_7b_lora.yaml",
#     "overrides": [
#       "training.num_train_epochs=1",
#       "training.max_steps=1000",
#       "training.eval_steps=250",
#       "training.save_steps=250",
#       "training.logging_steps=25",
#       "training.save_total_limit=2",
#       "training.ddp_find_unused_parameters=false",
#       "training.per_device_train_batch_size=1",
#       "training.per_device_eval_batch_size=2",
#       "training.gradient_accumulation_steps=8",
#       "data.max_train_samples=10000",
#       "data.max_eval_samples=500",
#       "data.max_source_length=1024",
#       "data.max_target_length=160",
#       "data.max_length=1184",
#       "generation.max_new_tokens=160",
#       "generation.num_beams=2",
#       "lora.r=16",
#       "lora.lora_alpha=32"
#     ]
#   }
# ]

# %% [markdown]
# ## Train And Evaluate
#
# Sau train, notebook evaluate ROUGE bang generation tren validation. Evaluation co the ton thoi gian vi causal LM generate cham hon seq2seq.

# %%
for exp in EXPERIMENTS:
    print('\n' + '='*100)
    print('TRAIN', exp['name'])
    train_causal(exp['name'], exp['config'], exp['overrides'], overwrite=OVERWRITE_RUNS)
    model_path = OUTPUT_ROOT / exp['name'] / 'best'
    print('EVAL', model_path)
    eval_causal(exp['name'] + '_eval', exp['config'], model_path, exp['overrides'], overwrite=OVERWRITE_EVALS)
    summarize_results()
# Out:
# ====================================================================================================
# TRAIN qwen3_1_7b_lora_4to6h_t4x2
# CMD: /usr/bin/python3 -m accelerate.commands.launch --multi_gpu --num_processes 2 --num_machines 1 --mixed_precision fp16 --dynamo_backend no -m vn_summarization.train_causal_lm --config configs/qwen3_1_7b_lora.yaml --set data.train_file=/kaggle/input/datasets/anhnguyen0812/nlp-vietnamese-sumarization/train-00000-of-00001.parquet --set data.valid_file=/kaggle/input/datasets/anhnguyen0812/nlp-vietnamese-sumarization/valid-00000-of-00001.parquet --set training.output_dir=/kaggle/working/summarization_outputs/qwen3_1_7b_lora_4to6h_t4x2 --set training.num_train_epochs=1 --set training.max_steps=1000 --set training.eval_steps=250 --set training.save_steps=250 --set training.logging_steps=25 --set training.save_total_limit=2 --set training.ddp_find_unused_parameters=false --set training.per_device_train_batch_size=1 --set training.per_device_eval_batch_size=2 --set training.gradient_accumulation_steps=8 --set data.max_train_samples=10000 --set data.max_eval_samples=500 --set data.max_source_length=1024 --set data.max_target_length=160 --set data.max_length=1184 --set generation.max_new_tokens=160 --set generation.num_beams=2 --set lora.r=16 --set lora.lora_alpha=32
# 2026-06-10 06:10:44.197277: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-06-10 06:10:44.197277: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1781071844.399844     106 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1781071844.399819     107 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1781071844.459325     107 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# E0000 00:00:1781071844.459331     106 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1781071844.959285     106 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1781071844.959284     107 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1781071844.959329     106 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1781071844.959332     106 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1781071844.959335     106 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1781071844.959326     107 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1781071844.959343     107 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1781071844.959348     107 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# `torch_dtype` is deprecated! Use `dtype` instead!
# `torch_dtype` is deprecated! Use `dtype` instead!
#
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# Fetching 2 files:  50%|█████     | 1/2 [00:15<00:15, 15.90s/it]
# Fetching 2 files: 100%|██████████| 2/2 [00:15<00:00,  7.95s/it]
#
# Fetching 2 files:  50%|█████     | 1/2 [00:15<00:15, 15.88s/it]
# Fetching 2 files: 100%|██████████| 2/2 [00:15<00:00,  7.94s/it]
#
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading checkpoint shards:  50%|█████     | 1/2 [00:04<00:04,  4.23s/it]
# Loading checkpoint shards:  50%|█████     | 1/2 [00:04<00:04,  4.52s/it]
# Loading checkpoint shards: 100%|██████████| 2/2 [00:04<00:00,  2.18s/it]
# Loading checkpoint shards: 100%|██████████| 2/2 [00:04<00:00,  2.49s/it]
#
# Loading checkpoint shards: 100%|██████████| 2/2 [00:05<00:00,  2.33s/it]
# Loading checkpoint shards: 100%|██████████| 2/2 [00:05<00:00,  2.66s/it]
# trainable params: 17,432,576 || all params: 1,738,007,552 || trainable%: 1.0030
#
# Generating train split: 0 examples [00:00, ? examples/s]trainable params: 17,432,576 || all params: 1,738,007,552 || trainable%: 1.0030
#
# Generating train split: 1000 examples [00:00, 2454.72 examples/s]
# Generating train split: 10775 examples [00:00, 24752.67 examples/s]
# Generating train split: 10775 examples [00:00, 19743.05 examples/s]
#
# Generating validation split: 0 examples [00:00, ? examples/s]
# Generating validation split: 1349 examples [00:00, 36583.51 examples/s]
#
# tokenizing causal lm (num_proc=1):   0%|          | 0/10000 [00:00<?, ? examples/s]
# tokenizing causal lm (num_proc=1):   0%|          | 0/10000 [00:00<?, ? examples/s]
# tokenizing causal lm (num_proc=1):  10%|█         | 1000/10000 [00:03<00:34, 257.62 examples/s]
# tokenizing causal lm (num_proc=1):  10%|█         | 1000/10000 [00:03<00:35, 254.16 examples/s]
# tokenizing causal lm (num_proc=1):  20%|██        | 2000/10000 [00:06<00:26, 300.22 examples/s]
# tokenizing causal lm (num_proc=1):  20%|██        | 2000/10000 [00:06<00:26, 298.76 examples/s]
# tokenizing causal lm (num_proc=1):  30%|███       | 3000/10000 [00:09<00:22, 318.02 examples/s]
# tokenizing causal lm (num_proc=1):  30%|███       | 3000/10000 [00:09<00:22, 315.99 examples/s]
# tokenizing causal lm (num_proc=1):  40%|████      | 4000/10000 [00:12<00:18, 329.00 examples/s]
# tokenizing causal lm (num_proc=1):  40%|████      | 4000/10000 [00:12<00:18, 326.14 examples/s]
# tokenizing causal lm (num_proc=1):  50%|█████     | 5000/10000 [00:15<00:15, 332.00 examples/s]
# tokenizing causal lm (num_proc=1):  50%|█████     | 5000/10000 [00:15<00:15, 327.35 examples/s]
# tokenizing causal lm (num_proc=1):  60%|██████    | 6000/10000 [00:18<00:11, 335.08 examples/s]
# tokenizing causal lm (num_proc=1):  60%|██████    | 6000/10000 [00:18<00:11, 333.94 examples/s]
# tokenizing causal lm (num_proc=1):  70%|███████   | 7000/10000 [00:21<00:08, 334.48 examples/s]
# tokenizing causal lm (num_proc=1):  70%|███████   | 7000/10000 [00:21<00:08, 335.24 examples/s]
# tokenizing causal lm (num_proc=1):  80%|████████  | 8000/10000 [00:24<00:05, 336.32 examples/s]
# tokenizing causal lm (num_proc=1):  80%|████████  | 8000/10000 [00:24<00:05, 336.88 examples/s]
# tokenizing causal lm (num_proc=1):  90%|█████████ | 9000/10000 [00:27<00:02, 340.71 examples/s]
# tokenizing causal lm (num_proc=1):  90%|█████████ | 9000/10000 [00:27<00:02, 337.70 examples/s]
# tokenizing causal lm (num_proc=1): 100%|██████████| 10000/10000 [00:30<00:00, 343.85 examples/s]
# tokenizing causal lm (num_proc=1): 100%|██████████| 10000/10000 [00:30<00:00, 339.80 examples/s]
# tokenizing causal lm (num_proc=1): 100%|██████████| 10000/10000 [00:30<00:00, 327.66 examples/s]
#
# tokenizing causal lm (num_proc=1):   0%|          | 0/500 [00:00<?, ? examples/s]
# tokenizing causal lm (num_proc=1): 100%|██████████| 10000/10000 [00:30<00:00, 325.98 examples/s]
#
# tokenizing causal lm (num_proc=1):   0%|          | 0/500 [00:00<?, ? examples/s]
# tokenizing causal lm (num_proc=1): 100%|██████████| 500/500 [00:02<00:00, 224.17 examples/s]
# tokenizing causal lm (num_proc=1): 100%|██████████| 500/500 [00:02<00:00, 221.48 examples/s]
# tokenizing causal lm (num_proc=1): 100%|██████████| 500/500 [00:03<00:00, 165.59 examples/s]
#
# tokenizing causal lm (num_proc=1): 100%|██████████| 500/500 [00:03<00:00, 154.67 examples/s]
# The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'bos_token_id': None}.
# The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'bos_token_id': None}.
#
#   0%|          | 0/1000 [00:00<?, ?it/s]You're using a Qwen2TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# You're using a Qwen2TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#
#   0%|          | 1/1000 [00:08<2:21:08,  8.48s/it]
#   0%|          | 2/1000 [00:15<2:11:22,  7.90s/it]
#   0%|          | 3/1000 [00:22<2:01:06,  7.29s/it]
#   0%|          | 4/1000 [00:29<1:57:54,  7.10s/it]
#   0%|          | 5/1000 [00:37<2:01:31,  7.33s/it]
#   1%|          | 6/1000 [00:44<2:03:36,  7.46s/it]
#   1%|          | 7/1000 [00:52<2:03:46,  7.48s/it]
#   1%|          | 8/1000 [00:59<2:03:15,  7.46s/it]
#   1%|          | 9/1000 [01:07<2:02:21,  7.41s/it]
#   1%|          | 10/1000 [01:14<2:03:25,  7.48s/it]
# generating:  98%|█████████▊| 246/250 [54:10<00:56, 14.02s/it]
# generating:  99%|█████████▉| 247/250 [54:25<00:42, 14.30s/it]
# generating:  99%|█████████▉| 248/250 [54:38<00:27, 13.88s/it]
# generating: 100%|█████████▉| 249/250 [54:49<00:12, 12.92s/it]
# generating: 100%|██████████| 250/250 [55:00<00:00, 12.49s/it]
# generating: 100%|██████████| 250/250 [55:00<00:00, 13.20s/it]
#
# Downloading builder script: 0.00B [00:00, ?B/s]
# Downloading builder script: 6.14kB [00:00, 14.9MB/s]
# {
#   "rouge1": 68.0518,
#   "rouge2": 32.2203,
#   "rougeL": 37.9005,
#   "gen_len": 87.244
# }
# CMD: /usr/bin/python3 -u -m vn_summarization.summarize_results --root /kaggle/working/summarization_outputs
# # Result Summary
#
# | run | model | lora | rouge1 | rouge2 | rougeL | gen_len | loss |
# | --- | --- | --- | --- | --- | --- | --- | --- |
# | qwen3_1_7b_lora_4to6h_t4x2_eval |  |  | 68.0518 | 32.2203 | 37.9005 | 87.2440 |  |
# | qwen3_1_7b_lora_4to6h_t4x2 | Qwen/Qwen3-1.7B | True |  |  |  |  | 0.5027 |
#
# CSV: /kaggle/working/summarization_outputs/summary_results.csv
# Best: /kaggle/working/summarization_outputs/best_run.json

# %% [markdown]
# ## Summarize And Export

# %%
summarize_results()
zip_path = WORKING / 'causal_lm_results.zip'
if zip_path.exists():
    zip_path.unlink()
keep_suffixes = {'.json', '.jsonl', '.csv', '.md', '.txt'}
files = [p for p in OUTPUT_ROOT.rglob('*') if p.is_file() and p.suffix in keep_suffixes]
with ZipFile(zip_path, 'w') as zf:
    for file in files:
        zf.write(file, file.relative_to(WORKING).as_posix())
print('ZIP', zip_path)
for file in sorted(files)[:80]:
    print(file)
# Out:
# CMD: /usr/bin/python3 -u -m vn_summarization.summarize_results --root /kaggle/working/summarization_outputs
# # Result Summary
#
# | run | model | lora | rouge1 | rouge2 | rougeL | gen_len | loss |
# | --- | --- | --- | --- | --- | --- | --- | --- |
# | qwen3_1_7b_lora_4to6h_t4x2_eval |  |  | 68.0518 | 32.2203 | 37.9005 | 87.2440 |  |
# | qwen3_1_7b_lora_4to6h_t4x2 | Qwen/Qwen3-1.7B | True |  |  |  |  | 0.5027 |
#
# CSV: /kaggle/working/summarization_outputs/summary_results.csv
# Best: /kaggle/working/summarization_outputs/best_run.json
# ZIP /kaggle/working/causal_lm_results.zip
# /kaggle/working/summarization_outputs/best_run.json
# /kaggle/working/summarization_outputs/qwen3_1_7b_lora_4to6h_t4x2/all_results.json
# /kaggle/working/summarization_outputs/qwen3_1_7b_lora_4to6h_t4x2/best/README.md
# /kaggle/working/summarization_outputs/qwen3_1_7b_lora_4to6h_t4x2/best/adapter_config.json
# /kaggle/working/summarization_outputs/qwen3_1_7b_lora_4to6h_t4x2/best/added_tokens.json
# /kaggle/working/summarization_outputs/qwen3_1_7b_lora_4to6h_t4x2/best/merges.txt
# /kaggle/working/summarization_outputs/qwen3_1_7b_lora_4to6h_t4x2/best/special_tokens_map.json
# /kaggle/working/summarization_outputs/qwen3_1_7b_lora_4to6h_t4x2/best/tokenizer.json
# /kaggle/working/summarization_outputs/qwen3_1_7b_lora_4to6h_t4x2/best/tokenizer_config.json
# /kaggle/working/summarization_outputs/qwen3_1_7b_lora_4to6h_t4x2/best/vocab.json
# /kaggle/working/summarization_outputs/qwen3_1_7b_lora_4to6h_t4x2/checkpoint-1000/README.md
# /kaggle/working/summarization_outputs/qwen3_1_7b_lora_4to6h_t4x2/checkpoint-1000/adapter_config.json
# /kaggle/working/summarization_outputs/qwen3_1_7b_lora_4to6h_t4x2/checkpoint-1000/added_tokens.json
# /kaggle/working/summarization_outputs/qwen3_1_7b_lora_4to6h_t4x2/checkpoint-1000/merges.txt
# /kaggle/working/summarization_outputs/qwen3_1_7b_lora_4to6h_t4x2/checkpoint-1000/special_tokens_map.json
# /kaggle/working/summarization_outputs/qwen3_1_7b_lora_4to6h_t4x2/checkpoint-1000/tokenizer.json
# /kaggle/working/summarization_outputs/qwen3_1_7b_lora_4to6h_t4x2/checkpoint-1000/tokenizer_config.json
# /kaggle/working/summarization_outputs/qwen3_1_7b_lora_4to6h_t4x2/checkpoint-1000/trainer_state.json
# /kaggle/working/summarization_outputs/qwen3_1_7b_lora_4to6h_t4x2/checkpoint-1000/vocab.json
# /kaggle/working/summarization_outputs/qwen3_1_7b_lora_4to6h_t4x2/checkpoint-750/README.md
# /kaggle/working/summarization_outputs/qwen3_1_7b_lora_4to6h_t4x2/checkpoint-750/adapter_config.json
# /kaggle/working/summarization_outputs/qwen3_1_7b_lora_4to6h_t4x2/checkpoint-750/added_tokens.json
# /kaggle/working/summarization_outputs/qwen3_1_7b_lora_4to6h_t4x2/checkpoint-750/merges.txt
# /kaggle/working/summarization_outputs/qwen3_1_7b_lora_4to6h_t4x2/checkpoint-750/special_tokens_map.json
# /kaggle/working/summarization_outputs/qwen3_1_7b_lora_4to6h_t4x2/checkpoint-750/tokenizer.json
# /kaggle/working/summarization_outputs/qwen3_1_7b_lora_4to6h_t4x2/checkpoint-750/tokenizer_config.json
# /kaggle/working/summarization_outputs/qwen3_1_7b_lora_4to6h_t4x2/checkpoint-750/trainer_state.json
# /kaggle/working/summarization_outputs/qwen3_1_7b_lora_4to6h_t4x2/checkpoint-750/vocab.json
# /kaggle/working/summarization_outputs/qwen3_1_7b_lora_4to6h_t4x2/eval_results.json
# /kaggle/working/summarization_outputs/qwen3_1_7b_lora_4to6h_t4x2/resolved_config.json
# /kaggle/working/summarization_outputs/qwen3_1_7b_lora_4to6h_t4x2/train_results.json
# /kaggle/working/summarization_outputs/qwen3_1_7b_lora_4to6h_t4x2/trainer_state.json
# /kaggle/working/summarization_outputs/qwen3_1_7b_lora_4to6h_t4x2_eval/predictions_valid.jsonl
# /kaggle/working/summarization_outputs/qwen3_1_7b_lora_4to6h_t4x2_eval/validation_metrics.json
# /kaggle/working/summarization_outputs/summary_results.csv
# /kaggle/working/summarization_outputs/summary_results.md
